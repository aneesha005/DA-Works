# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the data
df=pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# To see the head part of the data
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# To see the tail part of the data
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
# These are the headings in the data set
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# To see the shape of the data
df.shape
# Out:
# (5110, 12)

# %% [markdown]
# it is the column size and row size.rows are 5110 and columns are 12 in the data

# %%
# Type of the data
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Baisic information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %%
#check the missing values in the data
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# bmi has null values

# %%
df["bmi"].fillna(df["bmi"].mean(),inplace=True)

# %% [markdown]
# replaced null values in bmi column with mean value

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.drop(columns=["id"],inplace=True)

# %% [markdown]
# id is irrelevant so dropped id

# %%
# To get the statistical insights  use describe
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  5110.000000  5110.000000
# mean     28.893237     0.048728
# std       7.698018     0.215320
# min      10.300000     0.000000
# 25%      23.800000     0.000000
# 50%      28.400000     0.000000
# 75%      32.800000     0.000000
# max      97.600000     1.000000

# %%
# These are the types of data
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df["work_type"].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %% [markdown]
# More peoples are worked in private it's 2925 of the strength . less peoples are not worked it's 22 of them

# %%
df["gender"].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %% [markdown]
# This dataset have females are 2994 and males are 2115 ,here female strengh high for comparitively

# %%
df["Residence_type"].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %% [markdown]
# 2596 peoples are in urban area and 2514 are in rural

# %%
plt.figure(figsize = (10, 7))
x = df["avg_glucose_level"]
plt.hist(x, bins = 15, color ="skyblue")
plt.title("hypertension and avg_glucose_level")
plt.xlabel("avg_glucose_level")
plt.ylabel("hypertension")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-291eeeb3d900> in <module>
#       2 x = df["avg_glucose_level"]
#       3 plt.hist(x, bins = 15, color ="skyblue")
# ----> 4 plt.title("hypertension and avg_glucose_level")
#       5 plt.xlabel("avg_glucose_level")
#       6 plt.ylabel("hypertension")
#
# TypeError: 'str' object is not callable

# %%
sns.countplot(df.stroke,hue=df.gender)
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='stroke', ylabel='count'>

# %% [markdown]
# The stroke happened peoples strength is almost similar for females and males

# %%
sns.countplot(df.work_type,hue=df.hypertension)
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='work_type', ylabel='count'>

# %% [markdown]
# private workers has more hypertension because there job stress is more than others

# %%
sns.countplot(df.Residence_type,hue=df.gender)
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Residence_type', ylabel='count'>

# %% [markdown]
# urban and rural population resides is almost equal

# %%
sns.countplot(df.smoking_status,hue=df.stroke)
# Out:
# C:\Users\91799\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>

# %%
#seaborn.catplot
sns.catplot(x='smoking_status',data=df,kind='count')

# %% [raw]
# smoking_status has high number of categories never smoked and unknown persons,
# most of them peoples are never smokers,
# comparitively few observation are there for the category formely smoked and smokers,
# so finally smokers strength is less

# %%
labels=["male","female","others"]
df["stroke"].value_counts().plot(kind='pie', title='stroke problem',labels=labels,figsize=(10,5))
plt.show()

# %% [markdown]
# comparatively, males have more stroke problems happened than the other two

# %%
#Heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
plt.plot()
# Out:
# []

# %% [markdown]
# correlation,avg_glucose_level have a positive correlation of hypertension, stroke has a positive correlation of BMI

# %%
sns.pairplot(data=df,kind='scatter',diag_kind='kde')

# %% [markdown]
# pairplot is the comparison of the graphs

# %% [markdown]
# # INSIGHTS
# #### 1.The given dateset contains some information regarding health data
# #### 2.There are 5110 rows × 12 columns in data set.
# #### 3.The attributes of the data are id,gender,age,hypertension,heart_disease,ever_married,work_type,residence_type,avg_glucose_level,bmi,smoking_status,stroke
# #### 4.BMI has null values, so replaced null values in the BMI column with a mean value
# #### 5.id is irrelevant, so dropped id
# #### 6.More people are working in private it's 2925 of the strength. fewer people are not working it's 22 of them
# #### 7.This dataset have females are 2994 and males are 2115 ,here female strengh high for comparitively
# #### 8.2596 peoples are in urban area and 2514 are in rural
# #### 9.The stroke happened peoples strength is almost similar for females and males
# #### 10.private workers has more hypertension because there job stress is more than others
# #### 11.urban and rural population resides is almost equal
# #### 12.smoking_status has high number of categories never smoked and unknown persons, most of them peoples are never smokers,comparitively few observation are there for the category formely smoked and smokers,so finally smokers strength is less
# #### 13.comparatively, males have more stroke problems happened than the other two
# #### 14.correlation,avg_glucose_level have a positive correlation of hypertension, stroke has a positive correlation of BMI
# #### 15.pairplot is the comparison of the graphs
